# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# === Paths ===
BASE = r"D:\Darryl\Coding\s_p\data"
summary_file = os.path.join(BASE, "processed", "cluster_summary_v2.csv")
report_dir = os.path.join(BASE, "reports")
os.makedirs(report_dir, exist_ok=True)

# === Load cluster summary ===
df = pd.read_csv(summary_file)
print(f"Loaded cluster summary: {len(df)} clusters")

# === Rank clusters ===
# By high-risk ratio
df_high_ratio = df.sort_values(["high_ratio", "n_messages"], ascending=[False, False])
# By high-risk count
df_high_count = df.sort_values("high_msgs", ascending=False)
# By average heuristic score
df_avg_score = df.sort_values("avg_score", ascending=False)

# === Save CSV reports ===
df_high_ratio.to_csv(os.path.join(report_dir, "clusters_ranked_by_high_ratio.csv"), index=False)
df_high_count.to_csv(os.path.join(report_dir, "clusters_ranked_by_high_count.csv"), index=False)
df_avg_score.to_csv(os.path.join(report_dir, "clusters_ranked_by_avg_score.csv"), index=False)
print("✅ Saved ranked reports (CSV) to:", report_dir)

# === Excel export with multiple sheets ===
excel_path = os.path.join(report_dir, "cluster_risk_reports.xlsx")
with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    df_high_ratio.to_excel(writer, sheet_name="High_Ratio", index=False)
    df_high_count.to_excel(writer, sheet_name="High_Count", index=False)
    df_avg_score.to_excel(writer, sheet_name="Avg_Score", index=False)
print(f"✅ Excel report saved -> {excel_path}")

# === Visualization (Top 15 by high risk count) ===
top_n = 15
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_high_count.head(top_n),
    x="high_msgs",
    y="canonical_template",
    palette="Reds_r"
)
plt.title(f"Top {top_n} High-Risk Clusters (by message count)")
plt.xlabel("High-Risk Messages")
plt.ylabel("Cluster Template")
plt.tight_layout()
plot_path = os.path.join(report_dir, "top_high_risk_clusters.png")
plt.savefig(plot_path, dpi=150)
plt.close()
print(f"📊 Saved plot -> {plot_path}")

# === Visualization (Top 15 by high risk ratio, only clusters with >5 messages) ===
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_high_ratio[df_high_ratio["n_messages"] > 5].head(top_n),
    x="high_ratio",
    y="canonical_template",
    palette="Reds_r"
)
plt.title(f"Top {top_n} High-Risk Clusters (by ratio, min 5 msgs)")
plt.xlabel("High-Risk Ratio")
plt.ylabel("Cluster Template")
plt.tight_layout()
plot_path = os.path.join(report_dir, "top_high_risk_clusters_ratio.png")
plt.savefig(plot_path, dpi=150)
plt.close()
print(f"📊 Saved plot -> {plot_path}")
# Out:
# Loaded cluster summary: 1124 clusters
# ✅ Saved ranked reports (CSV) to: D:\Darryl\Coding\s_p\data\reports
# ✅ Excel report saved -> D:\Darryl\Coding\s_p\data\reports\cluster_risk_reports.xlsx
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120282 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL G}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120290 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120279 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120288 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL M}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120293 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL R}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120289 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL N}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120284 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120295 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL T}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120276 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120280 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120294 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL S}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120296 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120278 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120283 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL H}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120287 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL L}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120281 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120285 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL J}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120286 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL K}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120291 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL P}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120297 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL V}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120277 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Glyph 120300 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL Y}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:52: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120282 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL G}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120290 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL O}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120279 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL D}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120288 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL M}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120293 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL R}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120289 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL N}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120284 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL I}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120295 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL T}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120276 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120280 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL E}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120294 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL S}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120296 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL U}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120278 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL C}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120283 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL H}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120287 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL L}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120281 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL F}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120285 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL J}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120286 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL K}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120291 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL P}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120297 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL V}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120277 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL B}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:54: UserWarning: Glyph 120300 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL Y}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# 📊 Saved plot -> D:\Darryl\Coding\s_p\data\reports\top_high_risk_clusters.png
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120282 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL G}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120290 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120279 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120288 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL M}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120293 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL R}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120289 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL N}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120284 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120295 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL T}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120276 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120280 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120294 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL S}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120296 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120278 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120283 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL H}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120287 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL L}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120281 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120285 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL J}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120286 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL K}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120291 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL P}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120297 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL V}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120277 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 120300 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL Y}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2343 (\N{DEVANAGARI LETTER DHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2313 (\N{DEVANAGARI LETTER U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2357 (\N{DEVANAGARI LETTER VA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2333 (\N{DEVANAGARI LETTER JHA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2354 (\N{DEVANAGARI LETTER LA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:69: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120282 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL G}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120290 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL O}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120279 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL D}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120288 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL M}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120293 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL R}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120289 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL N}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120284 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL I}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120295 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL T}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120276 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120280 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL E}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120294 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL S}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120296 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL U}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120278 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL C}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120283 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL H}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120287 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL L}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120281 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL F}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120285 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL J}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120286 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL K}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120291 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL P}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120297 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL V}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120277 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL B}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 120300 (\N{MATHEMATICAL SANS-SERIF BOLD CAPITAL Y}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2343 (\N{DEVANAGARI LETTER DHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2313 (\N{DEVANAGARI LETTER U}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2357 (\N{DEVANAGARI LETTER VA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2333 (\N{DEVANAGARI LETTER JHA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2354 (\N{DEVANAGARI LETTER LA}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# C:\Users\Darryl\AppData\Local\Temp\ipykernel_16004\3779171567.py:71: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path, dpi=150)
# 📊 Saved plot -> D:\Darryl\Coding\s_p\data\reports\top_high_risk_clusters_ratio.png
