# %%
import pandas as pd
import numpy as np
import re
import unicodedata
from pathlib import Path

# ------------------------------------------------------------------
# 1. Paths
# ------------------------------------------------------------------
RAW_DIR = Path(r"D:\Darryl\Coding\s_p\data\raw")
PROCESSED_DIR = Path(r"D:\Darryl\Coding\s_p\data\processed")

src_file = RAW_DIR / "sebi_investment_advisors.csv"
out_clean_csv = PROCESSED_DIR / "sebi_investment_advisors_cleaned.csv"

# ------------------------------------------------------------------
# 2. Load CSV with correct header row
# ------------------------------------------------------------------
df = pd.read_csv(src_file, skiprows=2)   # skip the first 2 junk rows

print("Columns loaded:", df.columns.tolist()[:10], "...")  # peek at first few col names

# ------------------------------------------------------------------
# 3. Clean column names
# ------------------------------------------------------------------
def clean_col(c):
    c = unicodedata.normalize("NFKC", str(c))
    c = c.strip().lower()
    c = re.sub(r"[\s/\\\-]+", "_", c)
    c = re.sub(r"[^\w_]", "", c)
    c = re.sub(r"_+", "_", c).strip("_")
    return c

df.columns = [clean_col(c) for c in df.columns]

# ------------------------------------------------------------------
# 4. Helper functions
# ------------------------------------------------------------------
def extract_sebi_reg(s):
    if pd.isna(s): return np.nan
    s = str(s).upper().replace(" ", "")
    m = re.search(r"(INA\d{5,})", s)
    return m.group(1) if m else np.nan

EMAIL_RE = re.compile(r"[A-Z0-9._%+\-]+@[A-Z0-9.\-]+\.[A-Z]{2,}", re.I)
def split_emails(s):
    if pd.isna(s): return []
    s = s.replace(";", ",").replace("/", ",")
    return [e.strip().lower() for e in s.split(",") if EMAIL_RE.fullmatch(e.strip())]

def only_digits(s): 
    return re.sub(r"\D", "", str(s))

def normalize_in_phone(num):
    d = only_digits(num)
    if d.startswith("91") and len(d) == 12: 
        d = d[2:]
    if d.startswith("0") and len(d) == 11: 
        d = d[1:]
    if len(d) == 10: 
        return "+91" + d
    return "+91" + d if d else np.nan

def split_phones(s):
    if pd.isna(s): return []
    s = re.sub(r"[;/|]", ",", str(s))
    nums = []
    for p in s.split(","):
        norm = normalize_in_phone(p)
        if norm: nums.append(norm)
    return list(dict.fromkeys(nums))

def parse_date(s):
    try: 
        return pd.to_datetime(s, errors="coerce", dayfirst=True)
    except: 
        return pd.NaT

def extract_pincode(s):
    if pd.isna(s): return np.nan
    m = re.search(r"\b\d{6}\b", str(s))
    return m.group(0) if m else np.nan

# ------------------------------------------------------------------
# 5. Apply cleaners
# ------------------------------------------------------------------
clean = df.copy()

if "registration_no" in clean.columns:
    clean["sebi_reg_no_norm"] = clean["registration_no"].map(extract_sebi_reg)

if "email_id" in clean.columns:
    emails = clean["email_id"].map(split_emails)
    clean["email_primary"] = emails.map(lambda x: x[0] if x else np.nan)
    clean["emails_all"] = emails.map(lambda x: ", ".join(x) if x else np.nan)

if "telephone" in clean.columns:
    phones = clean["telephone"].map(split_phones)
    clean["phone_primary"] = phones.map(lambda x: x[0] if x else np.nan)
    clean["phones_all"] = phones.map(lambda x: ", ".join(x) if x else np.nan)

if "from" in clean.columns:
    clean["reg_date"] = clean["from"].map(parse_date)

if "to" in clean.columns:
    clean["expiry_date"] = clean["to"].map(parse_date)
    clean["days_to_expiry"] = (clean["expiry_date"] - pd.Timestamp.today()).dt.days

if "pincode" in clean.columns:
    clean["pincode_norm"] = clean["pincode"].map(extract_pincode)
elif "address" in clean.columns:
    clean["pincode_norm"] = clean["address"].map(extract_pincode)

# ------------------------------------------------------------------
# 6. Fix pincode columns
# ------------------------------------------------------------------
if "pincode" in clean.columns:
    clean = clean.drop(columns=["pincode"])
if "pincode_norm" in clean.columns:
    clean = clean.rename(columns={"pincode_norm": "pincode"})

# ------------------------------------------------------------------
# 7. Save one cleaned file
# ------------------------------------------------------------------
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
clean.to_csv(out_clean_csv, index=False)
print(f"\nSaved cleaned CSV → {out_clean_csv}")

# ------------------------------------------------------------------
# 8. Preview
# ------------------------------------------------------------------
print(clean.head(10))
# Out:
# Columns loaded: ['Name', 'Registration No.', 'Contact Person', 'Address', 'Email-Id', 'Telephone', 'Fax', 'City', 'State', 'Pincode'] ...
#
# Saved cleaned CSV → D:\Darryl\Coding\s_p\data\processed\sebi_investment_advisors_cleaned.csv
#                                           name registration_no  \
# 0                                KAVITHA MENON    INA000000037
# 1                     PRAKASH CHANDRA PRAHARAJ    INA000000045
# 2           VALUEFY SOLUTIONS  PRIVATE LIMITED    INA000000060
# 3                     ICICI SECURITIES LIMITED    INA000000094
# 4               ASTEYA INVESTMENT MANAGERS LLP    INA000000276
# 5   SPT INVESTMENT ADVISORY SERVICES PVT. LTD.    INA000000326
# 6          V R WEALTH ADVISORS PRIVATE LIMITED    INA000000383
# 7  BARCLAYS SECURITIES (INDIA) PRIVATE LIMITED    INA000000391
# 8   PLAN AHEAD WEALTH ADVISORS PRIVATE LIMITED    INA000000409
# 9                             SANDIP SABHARWAL    INA000000425
#
#                            contact_person  \
# 0                           KAVITHA MENON
# 1                Prakash Chandra Praharaj
# 2                Mr. Sumeet Kumar Agrawal
# 3  Abhishake Mathur Senior Vice President
# 4                           MR. ARUN BHAL
# 5                            Vinod Ameria
# 6                              VIVEK REGE
# 7                        MS. ARUNIMA BASU
# 8                         Shalini  Dhawan
# 9                        SANDIP SABHARWAL
#
#                                              address  \
# 0  015, Workafella, 12,AK Estate,Off Veer Savarka...
# 1  219,Skylark Building,Sector 11,Near Railway st...
# 2  D-401, Tulip Valley of Flowers,, Thakur Villag...
# 3  ICICI VENTURE HOUSE, APPASAHEB MARATHE MARG, P...
# 4  4G/4H, SIDDHIVINAYAK CHAMBERS,, 643, GANDHI NA...
# 5                   6/40, TARDEO A.C. MARKET, TARDEO
# 6  507 , B Wing , Naman Midtown , Senapati Bapat ...
# 7  Nirlon Knowledge Park, Level 9, Block B 6, Off...
# 8  A-401, FAIRLINK CENTER, OFF ANDHERI LINK ROAD,...
# 9  2202,MARATHON HEIGHTS,PANDURANG BUDHKAR MARG, ...
#
#                                email_id      telephone            fax  \
# 0                cavithamenon@gmail.com   919821455882            NaN
# 1            Prakash.praharaj@gmail.com     2227575648     2227575648
# 2                    sumeet@valuefy.com   022 32264400   022 32264400
# 3  abhishake.mathur@icicisecurities.com     2240701382     2240701382
# 4            arun.bhal@asteyaglobal.com     2226514252     2226514252
# 5              compliance@sptulsian.com   912244442701   912244442701
# 6        vivekrege@vrwealthadvisors.com  0002266391480  0002266391480
# 7         arunima.basu@barclaysasia.com     2267315136     2267315136
# 8           shalini.dhawan@planahead.in   910026345000   910026345000
# 9                sandipsabh@yahoo.co.in     2230828575     2230828575
#
#           city        state  \
# 0       MUMBAI  MAHARASHTRA
# 1  NAVI MUMBAI  MAHARASHTRA
# 2       MUMBAI  MAHARASHTRA
# 3       MUMBAI  MAHARASHTRA
# 4       MUMBAI  MAHARASHTRA
# 5       MUMBAI  MAHARASHTRA
# 6       MUMBAI  MAHARASHTRA
# 7       MUMBAI  MAHARASHTRA
# 8       MUMBAI  MAHARASHTRA
# 9       MUMBAI  MAHARASHTRA
#
#                                             address1  ... country  \
# 0  015, Workafella, 12,AK Estate,Off Veer Savarka...  ...     NaN
# 1  Flat No B 701, Sawan Harmony,Plot No G 90-95, ...  ...     NaN
# 2  D-401, Tulip Valley of Flowers, Thakur Village...  ...     NaN
# 3  ICICI Centre, H.T.Parekh Marg, Near Juinagar R...  ...     NaN
# 4  4G/4H, Siddhivinayak Chambers, 643, Gandhi Nag...  ...     NaN
# 5                   6/40, TARDEO A.C. MARKET, TARDEO  ...     NaN
# 6  507 , B Wing , Naman Midtown , Senapati Bapat ...  ...     NaN
# 7  208, Ceejay House, Shiv Sagar Estate, Goregaon...  ...     NaN
# 8  A-207/208/209/402, Fairlink Centre, Off Andher...  ...     NaN
# 9  2202,Marathon Heights,Pandurang Budhkar Marg, ...  ...     NaN
#
#   sebi_reg_no_norm                         email_primary  \
# 0     INA000000037                cavithamenon@gmail.com
# 1     INA000000045            prakash.praharaj@gmail.com
# 2     INA000000060                    sumeet@valuefy.com
# 3     INA000000094  abhishake.mathur@icicisecurities.com
# 4     INA000000276            arun.bhal@asteyaglobal.com
# 5     INA000000326              compliance@sptulsian.com
# 6     INA000000383        vivekrege@vrwealthadvisors.com
# 7     INA000000391         arunima.basu@barclaysasia.com
# 8     INA000000409           shalini.dhawan@planahead.in
# 9     INA000000425                sandipsabh@yahoo.co.in
#
#                              emails_all     phone_primary        phones_all  \
# 0                cavithamenon@gmail.com     +919821455882     +919821455882
# 1            prakash.praharaj@gmail.com     +912227575648     +912227575648
# 2                    sumeet@valuefy.com     +912232264400     +912232264400
# 3  abhishake.mathur@icicisecurities.com     +912240701382     +912240701382
# 4            arun.bhal@asteyaglobal.com     +912226514252     +912226514252
# 5              compliance@sptulsian.com     +912244442701     +912244442701
# 6        vivekrege@vrwealthadvisors.com  +910002266391480  +910002266391480
# 7         arunima.basu@barclaysasia.com     +912267315136     +912267315136
# 8           shalini.dhawan@planahead.in     +910026345000     +910026345000
# 9                sandipsabh@yahoo.co.in     +912230828575     +912230828575
#
#     reg_date expiry_date  days_to_expiry pincode
# 0 2013-08-01         NaT             NaN  400062
# 1 2013-08-02         NaT             NaN  400614
# 2 2013-08-02         NaT             NaN  400101
# 3 2013-08-05         NaT             NaN  400025
# 4 2013-11-21         NaT             NaN  400051
# 5 2013-11-25         NaT             NaN  400034
# 6 2013-12-03         NaT             NaN  400013
# 7 2013-12-03         NaT             NaN  400063
# 8 2013-12-03         NaT             NaN  400058
# 9 2013-12-05         NaT             NaN  400013
#
# [10 rows x 28 columns]

# %%
import pandas as pd
import numpy as np
import re
import unicodedata
from pathlib import Path

# ------------------------------------------------------------------
# 1. Paths
# ------------------------------------------------------------------
RAW_DIR = Path(r"D:\Darryl\Coding\s_p\data\raw")
PROCESSED_DIR = Path(r"D:\Darryl\Coding\s_p\data\processed")

src_file = RAW_DIR / "sebi_research_analysts.csv"
out_clean_csv = PROCESSED_DIR / "sebi_research_analysts_cleaned.csv"

# ------------------------------------------------------------------
# 2. Load CSV with correct header row
# ------------------------------------------------------------------
df = pd.read_csv(src_file, skiprows=2)   # skip first 2 junk rows if same format

print("Columns loaded:", df.columns.tolist()[:10], "...")  # peek at first few col names

# ------------------------------------------------------------------
# 3. Clean column names
# ------------------------------------------------------------------
def clean_col(c):
    c = unicodedata.normalize("NFKC", str(c))
    c = c.strip().lower()
    c = re.sub(r"[\s/\\\-]+", "_", c)
    c = re.sub(r"[^\w_]", "", c)
    c = re.sub(r"_+", "_", c).strip("_")
    return c

df.columns = [clean_col(c) for c in df.columns]

# ------------------------------------------------------------------
# 4. Helper functions
# ------------------------------------------------------------------
def extract_sebi_reg(s):
    if pd.isna(s): return np.nan
    s = str(s).upper().replace(" ", "")
    m = re.search(r"(IN[A-Z]\d{5,})", s)
    return m.group(1) if m else np.nan

EMAIL_RE = re.compile(r"[A-Z0-9._%+\-]+@[A-Z0-9.\-]+\.[A-Z]{2,}", re.I)
def split_emails(s):
    if pd.isna(s): return []
    s = s.replace(";", ",").replace("/", ",")
    return [e.strip().lower() for e in s.split(",") if EMAIL_RE.fullmatch(e.strip())]

def only_digits(s): return re.sub(r"\D", "", str(s))

# normalize indian phones

def normalize_in_phone(num):
    d = only_digits(num)
    if d.startswith("91") and len(d) == 12: d = d[2:]
    if d.startswith("0") and len(d) == 11: d = d[1:]
    if len(d) == 10: return "+91" + d
    return "+91" + d if d else np.nan

def split_phones(s):
    if pd.isna(s): return []
    s = re.sub(r"[;/|]", ",", str(s))
    nums = []
    for p in s.split(","):
        norm = normalize_in_phone(p)
        if norm: nums.append(norm)
    return list(dict.fromkeys(nums))

def parse_date(s):
    try: return pd.to_datetime(s, errors="coerce", dayfirst=True)
    except: return pd.NaT

def extract_pincode(s):
    if pd.isna(s): return np.nan
    m = re.search(r"\b\d{6}\b", str(s))
    return m.group(0) if m else np.nan

# ------------------------------------------------------------------
# 5. Apply cleaners
# ------------------------------------------------------------------
clean = df.copy()

if "registration_no" in clean.columns:
    clean["sebi_reg_no_norm"] = clean["registration_no"].map(extract_sebi_reg)

if "email_id" in clean.columns:
    emails = clean["email_id"].map(split_emails)
    clean["email_primary"] = emails.map(lambda x: x[0] if x else np.nan)
    clean["emails_all"] = emails.map(lambda x: ", ".join(x) if x else np.nan)

if "telephone" in clean.columns:
    phones = clean["telephone"].map(split_phones)
    clean["phone_primary"] = phones.map(lambda x: x[0] if x else np.nan)
    clean["phones_all"] = phones.map(lambda x: ", ".join(x) if x else np.nan)

if "from" in clean.columns:
    clean["reg_date"] = clean["from"].map(parse_date)

if "to" in clean.columns:
    clean["expiry_date"] = clean["to"].map(parse_date)
    clean["days_to_expiry"] = (clean["expiry_date"] - pd.Timestamp.today()).dt.days

# fix pincode → no .0
if "pincode" in clean.columns:
    clean["pincode"] = clean["pincode"].map(extract_pincode)
else:
    clean["pincode"] = clean["address"].map(extract_pincode)

# ------------------------------------------------------------------
# 6. Save one cleaned file
# ------------------------------------------------------------------
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
clean.to_csv(out_clean_csv, index=False)
print(f"\nSaved cleaned CSV → {out_clean_csv}")

# ------------------------------------------------------------------
# 7. Preview
# ------------------------------------------------------------------
clean.head()
# Out:
# Columns loaded: ['Name', 'Registration No.', 'Contact Person', 'Address', 'Email-Id', 'Telephone', 'Fax', 'City', 'State', 'Pincode'] ...
#
# Saved cleaned CSV → D:\Darryl\Coding\s_p\data\processed\sebi_research_analysts_cleaned.csv
#                                                 name registration_no  \
# 0                  STAKEHOLDERS EMPOWERMENT SERVICES    INH000000016
# 1  INSTITUTIONAL INVESTOR ADVISORY SERVICES INDIA...    INH000000024
# 2                               DEEPAK KUMAR KANODIA    INH000000032
# 3                        BOB CAPITAL MARKETS LIMITED    INH000000040
# 4                       GEPL CAPITAL PRIVATE LIMITED    INH000000081
#
#           contact_person                                            address  \
# 0  MR. DEVENDRA BHANDARI  A202, MUKTANGAN COMPLEX,, UPPER GOVIND NAGAR, ...
# 1            AMIT TANDON  GROUND FLOOR, DGP HOUSE, 88-C, OLD PRABHADEVI ...
# 2   DEEPAK KUMAR KANODIA  Flat no. 201, E wing, Sai Mannat, Sector-34, K...
# 3      MR. GOLAK B PANDA  3RD FLOOR, UTI TOWER, BANDRA-KURLA COMPLEX, BA...
# 4     MR. SUBHASH SHARMA         D-21, DHANRAJ MAHAL,, C.S.M. MARG, COLABA,
#
#                               email_id     telephone           fax  \
# 0  devendra.bhandari@sesgovernance.com    2240220322    2240220322
# 1                  amit.tandon@iias.in    2222721575    2222721575
# 2            deepakkrkanodia@gmail.com  022 28392567  022 28392567
# 3               golak.panda@bobcaps.in    2266718535    2266718535
# 4              subhash@geplcapital.com    2266182445    2266182445
#
#           city        state pincode  ...         to  country  \
# 0       MUMBAI  MAHARASHTRA  400097  ...  Perpetual      NaN
# 1       MUMBAI  MAHARASHTRA  400025  ...  Perpetual      NaN
# 2  NAVI MUMBAI  MAHARASHTRA  400059  ...  Perpetual      NaN
# 3       MUMBAI  MAHARASHTRA  400051  ...  Perpetual      NaN
# 4       MUMBAI  MAHARASHTRA  400001  ...  Perpetual      NaN
#
#    sebi_reg_no_norm                        email_primary  \
# 0      INH000000016  devendra.bhandari@sesgovernance.com
# 1      INH000000024                  amit.tandon@iias.in
# 2      INH000000032            deepakkrkanodia@gmail.com
# 3      INH000000040               golak.panda@bobcaps.in
# 4      INH000000081              subhash@geplcapital.com
#
#                             emails_all  phone_primary     phones_all  \
# 0  devendra.bhandari@sesgovernance.com  +912240220322  +912240220322
# 1                  amit.tandon@iias.in  +912222721575  +912222721575
# 2            deepakkrkanodia@gmail.com  +912228392567  +912228392567
# 3               golak.panda@bobcaps.in  +912266718535  +912266718535
# 4              subhash@geplcapital.com  +912266182445  +912266182445
#
#     reg_date expiry_date  days_to_expiry
# 0 2015-01-20         NaT             NaN
# 1 2015-01-30         NaT             NaN
# 2 2015-02-04         NaT             NaN
# 3 2015-02-04         NaT             NaN
# 4 2015-02-10         NaT             NaN
#
# [5 rows x 28 columns]
